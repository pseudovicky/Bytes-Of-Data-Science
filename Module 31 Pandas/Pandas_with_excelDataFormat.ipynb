# %%
import pandas as pd
! pip3 install openpyxl
import openpyxl

# %%
df1 = pd.read_excel("New.xlsx")
df1
# Out:
#                        Country  Year   Rank  Total  S1: Demographic Pressures  \
# 0                      Somalia  2023    1st  111.9                       10.0
# 1                        Yemen  2023    2nd  108.9                        9.6
# 2                  South Sudan  2023    3rd  108.5                        9.7
# 3    Congo Democratic Republic  2023    4th  107.2                        9.7
# 4                        Syria  2023    5th  107.1                        7.4
# ..                         ...   ...    ...    ...                        ...
# 174                Switzerland  2023  175th   17.8                        2.4
# 175                New Zealand  2023  176th   16.7                        1.1
# 176                    Finland  2023  177th   16.0                        1.7
# 177                    Iceland  2023  178th   15.7                        1.5
# 178                     Norway  2023  179th   14.5                        1.4
#
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# Country                              object
# Year                                  int64
# Rank                                 object
# Total                               float64
# S1: Demographic Pressures           float64
# S2: Refugees and IDPs               float64
# C3: Group Grievance                 float64
# E3: Human Flight and Brain Drain    float64
# E2: Economic Inequality             float64
# E1: Economy                         float64
# P1: State Legitimacy                float64
# P2: Public Services                 float64
# P3: Human Rights                    float64
# C1: Security Apparatus              float64
# C2: Factionalized Elites            float64
# X1: External Intervention           float64
# dtype: object

# %%
df1.columns
# Out:
# Index(['Country', 'Year', 'Rank', 'Total', 'S1: Demographic Pressures',
#        'S2: Refugees and IDPs', 'C3: Group Grievance',
#        'E3: Human Flight and Brain Drain', 'E2: Economic Inequality',
#        'E1: Economy', 'P1: State Legitimacy', 'P2: Public Services',
#        'P3: Human Rights', 'C1: Security Apparatus',
#        'C2: Factionalized Elites', 'X1: External Intervention'],
#       dtype='object')

# %%
df1['Country']
# Out:
# 0                        Somalia
# 1                          Yemen
# 2                    South Sudan
# 3      Congo Democratic Republic
# 4                          Syria
#                  ...
# 174                  Switzerland
# 175                  New Zealand
# 176                      Finland
# 177                      Iceland
# 178                       Norway
# Name: Country, Length: 179, dtype: object

# %%
df1[['Country','Year','Rank']]
# Out:
#                        Country  Year   Rank
# 0                      Somalia  2023    1st
# 1                        Yemen  2023    2nd
# 2                  South Sudan  2023    3rd
# 3    Congo Democratic Republic  2023    4th
# 4                        Syria  2023    5th
# ..                         ...   ...    ...
# 174                Switzerland  2023  175th
# 175                New Zealand  2023  176th
# 176                    Finland  2023  177th
# 177                    Iceland  2023  178th
# 178                     Norway  2023  179th
#
# [179 rows x 3 columns]

# %%
df2 = pd.read_csv("/Users/vickykumar/BytesOfDataScience/Module 31 Pandas/contacts.csv")

# %%
df2.head(10)
# Out:
#    id  location_id  organization_id  service_id                name  \
# 0   1          1.0              NaN         NaN       Susan Houston
# 1   2          1.0              NaN         NaN  Christina Gonzalez
# 2   3          2.0              NaN         NaN        Brenda Brown
# 3   4          3.0              NaN         NaN  Howard Lader, LCSW
# 4   5          4.0              NaN         NaN  Kimberly Pesavento
# 5   6          5.0              NaN         NaN           Joe Bloom
# 6   7          6.0              NaN         NaN         Peter Olson
# 7   8          6.0              NaN         NaN        Bart Charlow
# 8   9          7.0              NaN         NaN        Bart Charlow
# 9  10          7.0              NaN         NaN        Barbara Kalt
#
#                                              title email department
# 0                 Director of Older Adult Services   NaN        NaN
# 1                                  Center Director   NaN        NaN
# ...

# %%
df2.columns
# Out:
# Index(['id', 'location_id', 'organization_id', 'service_id', 'name', 'title',
#        'email', 'department'],
#       dtype='object')

# %%
df2["location_id"]
# Out:
# 0      1.0
# 1      1.0
# 2      2.0
# 3      3.0
# 4      4.0
# 5      5.0
# 6      6.0
# 7      6.0
# 8      7.0
# 9      7.0
# 10     8.0
# 11     8.0
# 12     8.0
# 13     9.0
# 14     9.0
# 15    10.0
# 16    10.0
# 17    11.0
# 18    11.0
# 19    12.0
# 20    13.0
# 21    14.0
# 22    15.0
# 23    16.0
# 24    17.0
# 25    18.0
# 26    19.0
# 27    21.0
# 28    22.0
# 29     NaN
# 30     NaN
# Name: location_id, dtype: float64

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2[['location_id','name','email','id','title']]
# Out:
#     location_id                     name                   email  id  \
# 0           1.0            Susan Houston                     NaN   1
# 1           1.0       Christina Gonzalez                     NaN   2
# 2           2.0             Brenda Brown                     NaN   3
# 3           3.0       Howard Lader, LCSW                     NaN   4
# 4           4.0       Kimberly Pesavento                     NaN   5
# 5           5.0                Joe Bloom                     NaN   6
# 6           6.0              Peter Olson                     NaN   7
# 7           6.0             Bart Charlow                     NaN   8
# 8           7.0             Bart Charlow                     NaN   9
# 9           7.0             Barbara Kalt                     NaN  10
# 10          8.0  Marilyn Baker-Venturini                     NaN  11
# 11          8.0       Graciela Hernandez                     NaN  12
# 12          8.0            Julie Avelino                     NaN  13
# ...

# %%
type(df2['name'])
# Out:
# pandas.core.series.Series

# %%
type(df2[['name','title']])
# Out:
# pandas.core.frame.DataFrame

# %%
df2.tail(10)
# Out:
#     id  location_id  organization_id  service_id               name  \
# 21  22         14.0              NaN         NaN    Andres Espinoza
# 22  23         15.0              NaN         NaN      Jack Phillips
# 23  24         16.0              NaN         NaN          James Lee
# 24  25         17.0              NaN         NaN     Kenneth Gibson
# 25  26         18.0              NaN         NaN    Sharon Petersen
# 26  27         19.0              NaN         NaN    Sharon Petersen
# 27  28         21.0              NaN         NaN             Moncef
# 28  29         22.0              NaN         NaN  Suzanne Badenhoop
# 29  32          NaN              8.0         NaN   Elizabeth Feeney
# 30  36          NaN              NaN        22.0          Joe Smith
#
#                           title                   email             department
# 21  Captain, Commanding Officer                     NaN                    NaN
# ...

# %%
df2.tail(3)
# Out:
#     id  location_id  organization_id  service_id               name  \
# 28  29         22.0              NaN         NaN  Suzanne Badenhoop
# 29  32          NaN              8.0         NaN   Elizabeth Feeney
# 30  36          NaN              NaN        22.0          Joe Smith
#
#                   title                   email             department
# 28      Board President     suzanne@example.com              Referrals
# 29                  CEO     e.feeney@foobar.org             Operations
# 30  CalFresh Specialist  john.smith@example.org  CalFresh Applications

# %%
df2
